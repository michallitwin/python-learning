# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
mean = [0, 0]

cov = [
    [1.0, 0.9],
    [0.9, 1.0]
]

X = np.random.multivariate_normal(mean, cov, size=500)

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
scaled_data = scaler.transform(X)

# %%
pca = PCA(n_components=2)

# %%
pca.fit(X)
# Out:
# PCA(n_components=2)

# %%
x_pca = pca.transform(X)

# %%
plt.figure(figsize=(8,6))
plt.scatter(X[:,0],X[:,1])
plt.title('oryginal data')
# Out:
# Text(0.5, 1.0, 'oryginal data')

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1])
plt.xlabel('first principal component')
plt.ylabel('second principal component')
# Out:
# Text(0, 0.5, 'second principal component')

# %%
plt.figure(figsize=(8, 6))

plt.scatter(X[:, 0], X[:, 1], alpha=0.3, label='Oryginalne dane')

for length, vector in zip(pca.explained_variance_, pca.components_):
    v = vector * 2.5 * np.sqrt(length)  # długość proporcjonalna do wariancji
    plt.arrow(pca.mean_[0], pca.mean_[1], v[0], v[1],
              head_width=0.15, head_length=0.15, color='red', linewidth=2)

plt.xlabel('Cecha 1')
plt.ylabel('Cecha 2')
plt.title(f'PCA: PC1={pca.explained_variance_ratio_[0]*100:.1f}%, PC2={pca.explained_variance_ratio_[1]*100:.1f}%')
plt.axis('equal')
plt.grid(True)
plt.show()

# %%
#pierwsza skladowa okresla 95 proc informacji

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.9468831 0.0531169]

# %%
print(pca.components_)
# Out:
# [[ 0.71059679  0.70359946]
#  [-0.70359946  0.71059679]]

# %% [markdown]
# # zad 2

# %%
X_no_scaled = np.column_stack([X[:,0], X[:,1], X[:,1]*1000])

# %%
df = pd.DataFrame(X_no_scaled)
df
# Out:
#             0         1            2
# 0   -0.539595 -0.304028  -304.027665
# 1   -0.728010  0.538714   538.713664
# 2    1.770845  1.750999  1750.999104
# 3   -1.086141 -2.272562 -2272.562050
# 4    0.830144  0.428033   428.033457
# ..        ...       ...          ...
# 495  1.447725  1.592740  1592.739993
# 496  0.932275  0.178250   178.250444
# 497  1.219782  1.536843  1536.842975
# 498 -0.073164  0.509337   509.336803
# 499  1.466256  1.244981  1244.981400
#
# [500 rows x 3 columns]

# %%
pca_2 = PCA(n_components=2)
pca_2.fit(df)
# Out:
# PCA(n_components=2)

# %%
print(pca_2.explained_variance_ratio_)
# Out:
# [9.99999795e-01 2.04787819e-07]

# %%
print(pca_2.components_)
# Out:
# [[ 9.01696733e-04  9.99999093e-04  9.99999093e-01]
#  [ 9.99999593e-01 -9.01696282e-07 -9.01696282e-04]]

# %%
#po skalowaniu

# %%
scaler = StandardScaler()
scaler.fit(df)
scaled_data_2 = scaler.transform(df)

# %%
pca_scaled = PCA(n_components=2)
pca_scaled.fit(scaled_data_2)
# Out:
# PCA(n_components=2)

# %%
print(pca_scaled.explained_variance_ratio_)
# Out:
# [0.95308873 0.04691127]

# %%
print(pca_scaled.components_)
# Out:
# [[ 0.56220746  0.58477464  0.58477464]
#  [ 0.82699623 -0.39754071 -0.39754071]]

# %% [markdown]
# # zad 3

# %%
n_noise_list = [5,20,50]

for n_noise in n_noise_list:
    noise = np.random.normal(0,1, size=(500,n_noise))
    X_full = np.hstack([X,noise])
    X_scaled = StandardScaler().fit_transform(X_full)
    pca_2 = PCA().fit(X_scaled)
    pca_var = pca_2.explained_variance_ratio_ *100
    print(f"Liczba cech: {X_full.shape[1]} (2 sygnał + {n_noise} szum) -> PC1 wyjaśnia: {pca_var[0]:.2f}% wariancji a PC2 wyjaśnia ")
# Out:
# Liczba cech: 7 (2 sygnał + 5 szum) -> PC1 wyjaśnia: 27.45% wariancji a PC2 wyjaśnia
# Liczba cech: 22 (2 sygnał + 20 szum) -> PC1 wyjaśnia: 9.00% wariancji a PC2 wyjaśnia
# Liczba cech: 52 (2 sygnał + 50 szum) -> PC1 wyjaśnia: 4.07% wariancji a PC2 wyjaśnia
