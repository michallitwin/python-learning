# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
mean = [0, 0]

cov = [
    [1.0, 0.9],
    [0.9, 1.0]
]

X = np.random.multivariate_normal(mean, cov, size=500)

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
scaled_data = scaler.transform(X)

# %%
pca = PCA(n_components=2)

# %%
pca.fit(X)
# Out:
# PCA(n_components=2)

# %%
x_pca = pca.transform(X)

# %%
plt.figure(figsize=(8,6))
plt.scatter(X[:,0],X[:,1])
plt.title('oryginal data')
# Out:
# Text(0.5, 1.0, 'oryginal data')

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1])
plt.xlabel('first principal component')
plt.ylabel('second principal component')
# Out:
# Text(0, 0.5, 'second principal component')

# %%
plt.figure(figsize=(8, 6))

plt.scatter(X[:, 0], X[:, 1], alpha=0.3, label='Oryginalne dane')

for length, vector in zip(pca.explained_variance_, pca.components_):
    v = vector * 2.5 * np.sqrt(length)  # długość proporcjonalna do wariancji
    plt.arrow(pca.mean_[0], pca.mean_[1], v[0], v[1],
              head_width=0.15, head_length=0.15, color='red', linewidth=2)

plt.xlabel('Cecha 1')
plt.ylabel('Cecha 2')
plt.title(f'PCA: PC1={pca.explained_variance_ratio_[0]*100:.1f}%, PC2={pca.explained_variance_ratio_[1]*100:.1f}%')
plt.axis('equal')
plt.grid(True)
plt.show()

# %%
#pierwsza skladowa okresla 95 proc informacji

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.94094495 0.05905505]

# %%
print(pca.components_)
# Out:
# [[ 0.71145207  0.70273463]
#  [-0.70273463  0.71145207]]

# %% [markdown]
# # zad 2

# %%
X_no_scaled = np.column_stack([X[:,0], X[:,1], X[:,1]*1000])

# %%
df = pd.DataFrame(X_no_scaled)
df
# Out:
#             0         1            2
# 0    0.126768  0.487237   487.236928
# 1    0.029222  0.086512    86.512278
# 2    0.997547  1.036606  1036.605867
# 3    0.096612 -0.311606  -311.606348
# 4   -0.667029 -0.576864  -576.863773
# ..        ...       ...          ...
# 495 -0.018302  0.166394   166.394222
# 496  0.248465  1.455309  1455.309172
# 497  0.870501  0.384790   384.789618
# 498 -0.527884 -0.589901  -589.901069
# 499  0.365229 -0.013846   -13.846116
#
# [500 rows x 3 columns]

# %%
pca_2 = PCA(n_components=2)
pca_2.fit(df)
# Out:
# PCA(n_components=2)

# %%
print(pca_2.explained_variance_ratio_)
# Out:
# [9.99999773e-01 2.27182598e-07]

# %%
print(pca_2.components_)
# Out:
# [[ 8.91514856e-04  9.99999103e-04  9.99999103e-01]
#  [ 9.99999603e-01 -8.91513885e-07 -8.91514411e-04]]

# %%
#po skalowaniu

# %%
scaler = StandardScaler()
scaler.fit(df)
scaled_data_2 = scaler.transform(df)

# %%
pca_scaled = PCA(n_components=2)
pca_scaled.fit(scaled_data_2)
# Out:
# PCA(n_components=2)

# %%
print(pca_scaled.explained_variance_ratio_)
# Out:
# [0.94788479 0.05211521]

# %%
print(pca_scaled.components_)
# Out:
# [[ 0.56030371  0.58568753  0.58568753]
#  [ 0.82828724 -0.39619455 -0.39619455]]

# %% [markdown]
# # zad 3

# %%
n_noise_list = [5,20,50]

for n_noise in n_noise_list:
    noise = np.random.normal(0,1, size=(500,n_noise))
    X_full = np.hstack([X,noise])
    X_scaled = StandardScaler().fit_transform(X_full)
    pca_2 = PCA().fit(X_scaled)
    pca_var = pca_2.explained_variance_ratio_ *100
    print(f"Liczba cech: {X_full.shape[1]} (2 sygnał + {n_noise} szum) -> PC1 wyjaśnia: {pca_var[0]:.2f}% wariancji a PC2 wyjaśnia {pca_var[1]}")
# Out:
# Liczba cech: 7 (2 sygnał + 5 szum) -> PC1 wyjaśnia: 27.44% wariancji a PC2 wyjaśnia 15.547069361503107
# Liczba cech: 22 (2 sygnał + 20 szum) -> PC1 wyjaśnia: 8.89% wariancji a PC2 wyjaśnia 5.966295590582561
# Liczba cech: 52 (2 sygnał + 50 szum) -> PC1 wyjaśnia: 4.05% wariancji a PC2 wyjaśnia 3.1845160102494345
